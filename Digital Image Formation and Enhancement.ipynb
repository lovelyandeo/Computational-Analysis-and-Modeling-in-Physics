# %%
import numpy as np
import matplotlib.pyplot as plt
N = 200 #the higher num is the finer 
x = np.linspace(-1,1,num = N)
y = x
X,Y = np.meshgrid(x,y)
R = np.sqrt(X**2 + Y**2)
A = np.zeros(np.shape(R)) 
A[np.where(R<0.5)] = 1.0

#display as an image
plt.imshow(A, cmap = "gray")

#display as a 3D surface in Cartesian coordinates
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
ax = Axes3D(fig) 
ax.plot_surface(X,Y,A)
# Out:
# /var/folders/nd/l3h_t2k14fqdnbr6dbvvblth0000gn/T/ipykernel_58683/738207444.py:17: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
from turtle import Turtle
tor = Turtle()

tor.fillcolor("yellow")
for iterations in range(6):

    tor.begin_fill()
    for comb in range(6):
        tor.forward(60)
        tor.right(60)
    tor.end_fill()

    tor.forward(60)
    tor.left(60)

# %%
from turtle import Turtle
tor = Turtle()

tor.fillcolor("yellow")
for second in range(12):
    for iterations in range(6):
        tor.begin_fill()
        for comb in range(6):
            tor.forward(60)
            tor.right(60)
        tor.end_fill()
        tor.forward(60)
        tor.left(60)
    tor.forward(60)
    tor.left(60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/lovelyandeo/Documents/GitHub/AP157-Computational-Analysis-and-Modeling-in-Physics/Digital Image Formation and Enhancement.ipynb Cell 4 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/lovelyandeo/Documents/GitHub/AP157-Computational-Analysis-and-Modeling-in-Physics/Digital%20Image%20Formation%20and%20Enhancement.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> tor.begin_fill()
#       <a href='vscode-notebook-cell:/Users/lovelyandeo/Documents/GitHub/AP157-Computational-Analysis-and-Modeling-in-Physics/Digital%20Image%20Formation%20and%20Enhancement.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> for comb in range(6):
# ...

# %%
from turtle import Turtle

stage.set_background_color("white")
sprite = turtle.Turtle()
sprite.set_speed(2000)
sprite.pen_down()
sprite.pen_width(200000)
sprite.set_color("white")
sprite.move_up(1200)
sprite.move_down(2400)
sprite = turtle.Turtle()
sprite.set_speed(15)
sprite.pen_up()
sprite.set_color("blue")
sprite.move_up(50)
sprite.move_left(110)
sprite.pen_down()
sprite.pen_width(10)
sprite.circle(50)
sprite.pen_up()
sprite.set_color("yellow")
sprite.move_down(40)
sprite.move_right(60)
sprite.pen_down()
sprite.pen_width(10)
sprite.circle(50)
sprite.pen_up()
sprite.set_color("green")
sprite.move_right(130)
sprite.pen_down()
sprite.pen_width(10)
sprite.circle(50)
sprite.pen_up()
sprite.set_color("red")
sprite.move_up(40)
sprite.move_right(60)
sprite.pen_down()
sprite.pen_width(10)
sprite.circle(50)
sprite.pen_up()
sprite.set_color("black")
sprite.move_left(125)
sprite.pen_down()
sprite.pen_width(10)
sprite.circle(50)
text = codesters.Text("The Olympics Logo", 100, -100, "black")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/lovelyandeo/Documents/GitHub/AP157-Computational-Analysis-and-Modeling-in-Physics/Digital Image Formation and Enhancement.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/lovelyandeo/Documents/GitHub/AP157-Computational-Analysis-and-Modeling-in-Physics/Digital%20Image%20Formation%20and%20Enhancement.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from turtle import Turtle
# ----> <a href='vscode-notebook-cell:/Users/lovelyandeo/Documents/GitHub/AP157-Computational-Analysis-and-Modeling-in-Physics/Digital%20Image%20Formation%20and%20Enhancement.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> stage.set_background_color("white")
# ...
